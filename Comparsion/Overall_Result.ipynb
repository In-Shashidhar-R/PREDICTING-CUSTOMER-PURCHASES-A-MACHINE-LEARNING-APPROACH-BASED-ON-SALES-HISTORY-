# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, roc_curve, auc, confusion_matrix, f1_score, precision_score, recall_score
import matplotlib.pyplot as plt

# loading the csv data to a Pandas DataFrame
heart_data = pd.read_csv('/content/heart (1).csv')

# Separate features (X) and target variable (Y)
X = heart_data.drop(columns='target', axis=1)
Y = heart_data['target']

# Split the data into training and testing sets
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, stratify=Y, random_state=2)

# Create a K-Nearest Neighbors model
model = KNeighborsClassifier(n_neighbors=3)  # You can adjust the number of neighbors as needed

# Training the K-Nearest Neighbors model with Training data
model.fit(X_train, Y_train)

# Accuracy on training data
X_train_prediction = model.predict(X_train)
training_data_accuracy = accuracy_score(X_train_prediction, Y_train)
print('Accuracy on Training data: ', training_data_accuracy)

# Predictions on the test set
Y_scores_knn = model.predict_proba(X_test)[:, 1]

# ROC Curve
fpr_knn, tpr_knn, thresholds_knn = roc_curve(Y_test, Y_scores_knn)
roc_auc_knn = auc(fpr_knn, tpr_knn)

# Confusion Matrix
conf_matrix_knn = confusion_matrix(Y_test, model.predict(X_test))

# F1 Score
f1_score_knn = f1_score(Y_test, model.predict(X_test))

# Precision
precision_knn = precision_score(Y_test, model.predict(X_test))

# Recall
recall_knn = recall_score(Y_test, model.predict(X_test))

# Overall Accuracy
overall_accuracy_knn = accuracy_score(Y_test, model.predict(X_test))

# Plot ROC Curve
plt.figure(figsize=(10, 6))
plt.plot(fpr_knn, tpr_knn, color='darkorange', lw=2, label='ROC curve (area = {:.2f})'.format(roc_auc_knn))
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc='lower right')
plt.show()

# Print results
print('Confusion Matrix:\n', conf_matrix_knn)
print('F1 Score: ', f1_score_knn)
print('Precision: ', precision_knn)
print('Recall: ', recall_knn)
print('Overall Accuracy: ', overall_accuracy_knn)
# Out:
# Accuracy on Training data:  0.9926829268292683
# Confusion Matrix:
#  [[94  6]
#  [ 7 98]]
# F1 Score:  0.937799043062201
# Precision:  0.9423076923076923
# Recall:  0.9333333333333333
# Overall Accuracy:  0.9365853658536586

# %% [markdown]
# **Navie Bayes**

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import accuracy_score, roc_curve, auc, confusion_matrix, f1_score, precision_score, recall_score
import matplotlib.pyplot as plt

# loading the csv data to a Pandas DataFrame
heart_data = pd.read_csv('/content/heart (1).csv')

# Separate features (X) and target variable (Y)
X = heart_data.drop(columns='target', axis=1)
Y = heart_data['target']

# Split the data into training and testing sets
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, stratify=Y, random_state=2)

# Create a Gaussian Naive Bayes model
model = GaussianNB()

# Training the Gaussian Naive Bayes model with Training data
model.fit(X_train, Y_train)

# Accuracy on training data
X_train_prediction = model.predict(X_train)
training_data_accuracy = accuracy_score(X_train_prediction, Y_train)
print('Accuracy on Training data: ', training_data_accuracy)

# Predictions on the test set
Y_scores_naive_bayes = model.predict_proba(X_test)[:, 1]

# ROC Curve
fpr_naive_bayes, tpr_naive_bayes, thresholds_naive_bayes = roc_curve(Y_test, Y_scores_naive_bayes)
roc_auc_naive_bayes = auc(fpr_naive_bayes, tpr_naive_bayes)

# Confusion Matrix
conf_matrix_naive_bayes = confusion_matrix(Y_test, model.predict(X_test))

# F1 Score
f1_score_naive_bayes = f1_score(Y_test, model.predict(X_test))

# Precision
precision_naive_bayes = precision_score(Y_test, model.predict(X_test))

# Recall
recall_naive_bayes = recall_score(Y_test, model.predict(X_test))

# Overall Accuracy
overall_accuracy_naive_bayes = accuracy_score(Y_test, model.predict(X_test))

# Plot ROC Curve
plt.figure(figsize=(10, 6))
plt.plot(fpr_naive_bayes, tpr_naive_bayes, color='darkorange', lw=2, label='ROC curve (area = {:.2f})'.format(roc_auc_naive_bayes))
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc='lower right')
plt.show()

# Print results
print('Confusion Matrix:\n', conf_matrix_naive_bayes)
print('F1 Score: ', f1_score_naive_bayes)
print('Precision: ', precision_naive_bayes)
print('Recall: ', recall_naive_bayes)
print('Overall Accuracy: ', overall_accuracy_naive_bayes)
# Out:
# Accuracy on Training data:  0.8390243902439024
# Confusion Matrix:
#  [[75 25]
#  [20 85]]
# F1 Score:  0.7906976744186046
# Precision:  0.7727272727272727
# Recall:  0.8095238095238095
# Overall Accuracy:  0.7804878048780488

# %% [markdown]
# ***SVM**

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, roc_curve, auc, confusion_matrix, f1_score, precision_score, recall_score
import matplotlib.pyplot as plt

# loading the csv data to a Pandas DataFrame
heart_data = pd.read_csv('/content/heart (1).csv')

# Separate features (X) and target variable (Y)
X = heart_data.drop(columns='target', axis=1)
Y = heart_data['target']

# Split the data into training and testing sets
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, stratify=Y, random_state=2)

# Create an SVM model
model = SVC(kernel='linear')  # You can adjust the kernel and other parameters as needed

# Training the SVM model with Training data
model.fit(X_train, Y_train)

# Accuracy on training data
X_train_prediction = model.predict(X_train)
training_data_accuracy = accuracy_score(X_train_prediction, Y_train)
print('Accuracy on Training data: ', training_data_accuracy)

# Predictions on the test set
Y_scores_svm = model.decision_function(X_test)

# ROC Curve
fpr_svm, tpr_svm, thresholds_svm = roc_curve(Y_test, Y_scores_svm)
roc_auc_svm = auc(fpr_svm, tpr_svm)

# Confusion Matrix
conf_matrix_svm = confusion_matrix(Y_test, model.predict(X_test))

# F1 Score
f1_score_svm = f1_score(Y_test, model.predict(X_test))

# Precision
precision_svm = precision_score(Y_test, model.predict(X_test))

# Recall
recall_svm = recall_score(Y_test, model.predict(X_test))

# Overall Accuracy
overall_accuracy_svm = accuracy_score(Y_test, model.predict(X_test))

# Plot ROC Curve
plt.figure(figsize=(10, 6))
plt.plot(fpr_svm, tpr_svm, color='darkorange', lw=2, label='ROC curve (area = {:.2f})'.format(roc_auc_svm))
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc='lower right')
plt.show()

# Print results
print('Confusion Matrix:\n', conf_matrix_svm)
print('F1 Score: ', f1_score_svm)
print('Precision: ', precision_svm)
print('Recall: ', recall_svm)
print('Overall Accuracy: ', overall_accuracy_svm)
# Out:
# Accuracy on Training data:  0.8695121951219512
# Confusion Matrix:
#  [[72 28]
#  [ 8 97]]
# F1 Score:  0.8434782608695652
# Precision:  0.776
# Recall:  0.9238095238095239
# Overall Accuracy:  0.824390243902439

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, roc_curve, auc, confusion_matrix, f1_score, precision_score, recall_score
import matplotlib.pyplot as plt

# loading the csv data to a Pandas DataFrame
heart_data = pd.read_csv('/content/heart (1).csv')

# Separate features (X) and target variable (Y)
X = heart_data.drop(columns='target', axis=1)
Y = heart_data['target']

# Split the data into training and testing sets
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, stratify=Y, random_state=2)

# Create a Logistic Regression model
model = LogisticRegression()  # You can adjust the parameters as needed

# Training the Logistic Regression model with Training data
model.fit(X_train, Y_train)

# Accuracy on training data
X_train_prediction = model.predict(X_train)
training_data_accuracy = accuracy_score(X_train_prediction, Y_train)
print('Accuracy on Training data: ', training_data_accuracy)

# Predictions on the test set
Y_scores_logistic = model.predict_proba(X_test)[:, 1]

# ROC Curve
fpr_logistic, tpr_logistic, thresholds_logistic = roc_curve(Y_test, Y_scores_logistic)
roc_auc_logistic = auc(fpr_logistic, tpr_logistic)

# Confusion Matrix
conf_matrix_logistic = confusion_matrix(Y_test, model.predict(X_test))

# F1 Score
f1_score_logistic = f1_score(Y_test, model.predict(X_test))

# Precision
precision_logistic = precision_score(Y_test, model.predict(X_test))

# Recall
recall_logistic = recall_score(Y_test, model.predict(X_test))

# Overall Accuracy
overall_accuracy_logistic = accuracy_score(Y_test, model.predict(X_test))

# Plot ROC Curve
plt.figure(figsize=(10, 6))
plt.plot(fpr_logistic, tpr_logistic, color='darkorange', lw=2, label='ROC curve (area = {:.2f})'.format(roc_auc_logistic))
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc='lower right')
plt.show()

# Print results
print('Confusion Matrix:\n', conf_matrix_logistic)
print('F1 Score: ', f1_score_logistic)
print('Precision: ', precision_logistic)
print('Recall: ', recall_logistic)
print('Overall Accuracy: ', overall_accuracy_logistic)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Accuracy on Training data:  0.8524390243902439
# Confusion Matrix:
#  [[72 28]
#  [12 93]]
# F1 Score:  0.8230088495575221
# Precision:  0.768595041322314
# Recall:  0.8857142857142857
# Overall Accuracy:  0.8048780487804879
